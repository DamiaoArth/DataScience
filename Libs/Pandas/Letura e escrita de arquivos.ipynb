# %% [markdown]
# # Leitura e Escrita de arquivos

# %% [markdown]
# ## Instalando e importando Dependêcias

# %%
# %pip install pandas 
import pandas as pd

# %% [markdown]
# ## Carregando um arquivo CSV

# %%
df = pd.read_csv('./components/files/atv1test1.csv', encoding='latin1', sep = ';')

# %%
df
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino
# 2  Pedro     34  Masculino
# 3  Joana     25   Feminino

# %% [markdown]
# ## Carregando um arquivo XLSX
# ### Necessário a instalação do **openpyxl**
# %pip install openpyxl

# %%
df = pd.read_excel('./components/files/atv1test1.xlsx')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 KB 4.4 MB/s eta 0:00:003.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino
# 2  Pedro     34  Masculino
# 3  Joana     25   Feminino

# %% [markdown]
# ## Carregando um arquivo da WIKI
# ### Necessário a instalação do **lxml package**
# %pip install lxml

# %%
tabela_wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_Pok%C3%A9mon')

# %%
type(tabela_wiki)

print(f'Total de tabelas {len(tabela_wiki)}')
# Out:
# Todtal de tabelas 18

# %%
tabela_wiki[2]
# Out:
#               Generation I                                 Generation II  \
#                      Dex #                   Name                  Dex #
# 0                        1             BulbasaurS                    152
# 1                        2                Ivysaur                    153
# 2                        3               Venusaur                    154
# 3                        4            CharmanderS                    155
# 4                        5             Charmeleon                    156
# ..                     ...                    ...                    ...
# 151  No additional Pokémon  No additional Pokémon  No additional Pokémon
# 152  No additional Pokémon  No additional Pokémon  No additional Pokémon
# 153  No additional Pokémon  No additional Pokémon  No additional Pokémon
# 154  No additional Pokémon  No additional Pokémon  No additional Pokémon
# 155  No additional Pokémon  No additional Pokémon  No additional Pokémon
#
# ...

# %% [markdown]
# ## Procurar Uma tabela por texto específico
# ### Necessário a intalação do **beautifulsoup4**
# %pip install beautifulsoup4

# %%
tabela_wiki_species = pd.read_html('https://en.wikipedia.org/wiki/List_of_Pok%C3%A9mon', match='Pokémon species glossary')

# %%
tabela_wiki_species[0]
# Out:
#              Key                                                     \
#   Color / Letter                                            Meaning
# 0              S  Starter Pokémon (also known as First Partner P...
# 1              F                                 Fossil Pokémon[32]
# 2              B                                   Baby Pokémon[33]
# 3              L                                  Legendary Pokémon
# 4              M                                   Mythical Pokémon
# 5              U                                        Ultra Beast
# 6              P                                    Paradox Pokémon
#
#                                                                          \
#                                          Description Unnamed: 3_level_1
# 0  The first Pokémon a player is able to obtain i...                NaN
# 1  Ancient Pokémon only obtained by resurrecting ...                NaN
# ...
