# %% [markdown]
# ## 2.1 `scipy.stats`: Estatísticas e Testes de Hipótese

# %%
# %pip install scipy

from scipy import stats
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: scipy in c:\users\damio\onedrive\documentos\arthur\celepar\datacience\.venv\lib\site-packages (1.15.0)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\damio\onedrive\documentos\arthur\celepar\datacience\.venv\lib\site-packages (from scipy) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Criando dados de exemplo

# %%
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# %% [markdown]
# # Estatísticas descritivas

# %%
mean = np.mean(data)
std_dev = np.std(data)
print(f"Média: {mean}, Desvio Padrão: {std_dev}")
# Out:
# Média: 50.193320558223256, Desvio Padrão: 9.787262077473542

# %% [markdown]
# # Teste de normalidade

# %%
stat, p_value = stats.shapiro(data)
print(f"Teste de Shapiro-Wilk: estatística={stat:.3f}, p-valor={p_value:.3f}")
# Out:
# Teste de Shapiro-Wilk: estatística=0.999, p-valor=0.627

# %% [markdown]
# # Visualização

# %%
sns.histplot(data, kde=True)
plt.title("Distribuição dos Dados")
plt.show()
